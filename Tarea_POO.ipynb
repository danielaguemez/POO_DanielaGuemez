# %% [markdown]
# ## Tarea 1. Primera parte.

# %% [markdown]
# 1.   Genera una lista que consista de $20$ números que estén en el intervalo $[-1,1]$. Llámala `Lista_1`.
# 2.   Genera una lista que consista de $20$ números que sean enteros en el intervalo $[1500, 3000]$. Llámala `Lista_2`.
# 3. Crea un diccionario cuyas llaves sean "**CapSmall**" y "**CapLarge**" y sus valores sean la `Lista_1` y `Lista_2`, respectivamente.
# 4. Crea un `DataFrame` a partir del diccionario del punto anterior. Llámalo df.
# 5. Reindexa los índices poniendo Año 1$,...,$ Año 20.
# 6. Realiza una explicación de la estadística descriptiva de tu `DataFrame`.
# 7. ¿Cuál es el valor mínimo de la columna "**CapSmall**"?
# 8. ¿Cuál es "**CapLarge**" promedio del año 10 al año 20.
# 9. Realiza una gráfica de Año contra "**CapLarge**".
# 10. Muestra el `DataFrame` que obtienes si tomas aquellos valores de "**CapLarge**" mayores a $2000$. ¿Cuál es la dimensión (shape) de tu nueva base de datos?

# %%
import numpy as np

# %%
#1
Lista_1=np.random.uniform(low=-1, high=1, size=20 )
Lista_1
# Out:
# array([-0.9798866 , -0.72033577, -0.51414813, -0.25232431,  0.80187042,
#        -0.88725792, -0.00716823,  0.65372517,  0.4780275 , -0.25044109,
#        -0.4828032 , -0.15151186,  0.09468207,  0.66832649,  0.91388868,
#         0.29430698, -0.84706549,  0.09949179,  0.87277951,  0.32049296])

# %%
#2
Lista_2=np.random.randint(low=1500, high=3000, size=20)
Lista_2
# Out:
# array([1660, 2022, 2275, 2682, 1991, 2770, 2377, 2396, 2379, 1942, 2682,
#        2287, 2843, 2253, 1511, 2151, 1887, 1594, 2244, 2322])

# %%
#3
Diccionario ={"CapSmall":Lista_1, "CapLarge":Lista_2}
Diccionario
# Out:
# {'CapSmall': array([-0.9798866 , -0.72033577, -0.51414813, -0.25232431,  0.80187042,
#         -0.88725792, -0.00716823,  0.65372517,  0.4780275 , -0.25044109,
#         -0.4828032 , -0.15151186,  0.09468207,  0.66832649,  0.91388868,
#          0.29430698, -0.84706549,  0.09949179,  0.87277951,  0.32049296]),
#  'CapLarge': array([1660, 2022, 2275, 2682, 1991, 2770, 2377, 2396, 2379, 1942, 2682,
#         2287, 2843, 2253, 1511, 2151, 1887, 1594, 2244, 2322])}

# %%
import pandas as pd

# %%
#4/5
df=pd.DataFrame(Diccionario,index=["Año 1", "Año 2", "Año 3", "Año 4", "Año 5", "Año 6", "Año 7", "Año 8", "Año 9", "Año 10", "Año 11", "Año 12", "Año 13", "Año 14", "Año 15", "Año 16", "Año 17", "Año 18", "Año 19", "Año 20"])
df
# Out:
#         CapSmall  CapLarge
# Año 1  -0.979887      1660
# Año 2  -0.720336      2022
# Año 3  -0.514148      2275
# Año 4  -0.252324      2682
# Año 5   0.801870      1991
# Año 6  -0.887258      2770
# Año 7  -0.007168      2377
# Año 8   0.653725      2396
# Año 9   0.478028      2379
# Año 10 -0.250441      1942
# Año 11 -0.482803      2682
# Año 12 -0.151512      2287
# Año 13  0.094682      2843
# Año 14  0.668326      2253
# Año 15  0.913889      1511
# Año 16  0.294307      2151
# Año 17 -0.847065      1887
# Año 18  0.099492      1594
# Año 19  0.872780      2244
# Año 20  0.320493      2322

# %%
#6
df.describe()
# Out:
#         CapSmall     CapLarge
# count  20.000000    20.000000
# mean    0.005232  2213.400000
# std     0.614764   377.656959
# min    -0.979887  1511.000000
# 25%    -0.490639  1978.750000
# 50%     0.043757  2264.000000
# 75%     0.521952  2383.250000
# max     0.913889  2843.000000

# %%
#7
min(Lista_1)
# Out:
# -0.9798865986015801

# %%
#8
CapLarge_promedio=df.iloc[10:20]
CapLarge_promedio=CapLarge_promedio.drop(columns="CapSmall")
CapLarge_promedio
# Out:
#         CapLarge
# Año 11      2682
# Año 12      2287
# Año 13      2843
# Año 14      2253
# Año 15      1511
# Año 16      2151
# Año 17      1887
# Año 18      1594
# Año 19      2244
# Año 20      2322

# %%
#Promedio 8
CapLarge_promedio.mean()
# Out:
# CapLarge    2177.4
# dtype: float64

# %%
#9
df=df.drop(columns="CapSmall")

# %%
#Ejercicio 10
filtro = df["CapLarge"] > 2000
nueva_df = df[filtro]
nueva_df
# Out:
#         CapLarge
# Año 2       2022
# Año 3       2275
# Año 4       2682
# Año 6       2770
# Año 7       2377
# Año 8       2396
# Año 9       2379
# Año 11      2682
# Año 12      2287
# Año 13      2843
# Año 14      2253
# Año 16      2151
# Año 19      2244
# Año 20      2322

# %%
nueva_df.shape
# Out:
# (14, 1)
